# %% [markdown]
# ### 1. Ethical issues with computer vision applications
# [Wall Street Journal](https://www.natlawreview.com/article/facial-recognition-technology-surges-organizations-face-privacy-and-cybersecurity)

# %% [markdown]
# Personal thoughts : By increasing the accuracy of the technology and creating a robust privacy and data protection program is essential to decrease and possibly avoid any kind of fraud.

# %% [markdown]
# ### 2.Generate an image from a caption

# %%
# %matplotlib inline
from IPython.display import Image
Image('image.png')

# %% [markdown]
# - People on Couch
# - Poeple on couch playing video games

# %% [markdown]
# The photo is not that accurate cause playing video games is not that obvious.

# %% [markdown]
# 3. [Dog and Cats](https://thedatafrog.com/en/articles/dogs-vs-cats/)

# %% [markdown]
# <b>Summary:
#
# If a network is complex enough (if it has enough parameters), it can start overfitting , which means that it is able to learn the specific features of the images in the training dataset.
# So we need a way to turn our images, now files on disk, into batches of data arrays in memory that can be fed to the network during training.
# We will train our neural network on a subset of the dog and cat images called the training dataset .
# Here, we just need to make sure that the format of all images is the same, as the convolutional neural network that we're going to use has a fixed number of inputs.
# It should however be noted that even if we decide to reject cartoon images for training, the trained network might be able to identify them correctly.
# To make sure that overfitting does not occur, we will evaluate the performance of the network on a validation dataset , disjoint from the training dataset.
# In this article, you will build a convolutional neural network from scratch to classify images into two categories, dog or cat, with a 92% accuracy.
# Still, that's only a guess, and a guess is not enough! we need to be sure, or we take the risk to feed our network with mislabeled images (and garbage in, garbage out).

# %% [markdown]
# <b>Improving:
#
# Utilize the power of deep neural networks and add on some more layers to the architecture. These additional layers will allow the network to learn a more complex classification function that may improve the classification performance.
