# %% [markdown]
# # Visiting northen light in Norway

# %% [markdown]
# Visiting northen light in Norway

# %%
Name = input("Please enter your name: ")
print("Hi", Name)
# Out:
# Please enter your name: archie
# Hi archie

# %% [markdown]
# ![archie.jpg](attachment:archie.jpg)

# %%
Destination = input("please enter your destination: ")
# Out:
# please enter your destination: Norway

# %% [markdown]
# ![Northern_Lights_Tromso_Norway.jpg](attachment:Northern_Lights_Tromso_Norway.jpg)

# %% [markdown]
# * <font color = Blue> <b> <i> Take a train juorney
# *  <font color = red>Visit the arctice circle
# * <font color = green> Skiing

# %% [markdown]
# [Video of destination](https://www.youtube.com/watch?v=izYiDDt6d8s)
